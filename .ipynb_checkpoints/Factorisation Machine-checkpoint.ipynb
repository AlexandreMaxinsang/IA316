# %%
import requests
import time
import numpy as np
import pandas as pd
import copy
from keras.layers import Input, Embedding, Flatten, Dot, Concatenate, Dropout, Dense
from keras.models import Model

# %%
#attributes 
USER_ID = 'IAHIZPIW80WPGDW7P7JE'
BASE_URL = "http://35.180.178.243"
url_reset = BASE_URL + "/reset"
url_predict = BASE_URL + "/predict"
params = {"user_id" : USER_ID}

def load_data(url_reset,params) :
    r = requests.get(url=url_reset, params=params)
    data = r.json()
    return data

data = load_data(url_reset,params)
nb_users = data["nb_users"]
nb_items = data["nb_items"]
next_state = data["next_state"]

data.keys()
# Out:
# dict_keys(['action_history', 'nb_items', 'nb_users', 'next_state', 'rewards_history', 'state_history'])

# %%
blacklisted_set = set(("next_state","nb_items","nb_users"))
new_dict = {key : value for key, value in data.items() if key not in blacklisted_set}

df = pd.DataFrame(new_dict)
df.head()
# Out:
#    action_history  rewards_history  \
# 0               9       645.518587
# 1              11       102.941312
# 2              16       925.267997
# 3               5       337.393735
# 4              25       249.038114
#
#                                        state_history
# 0  [[10, 0, 281.3701299412495, 1.3366397537036412...
# 1  [[69, 0, 281.3701299412495, 0.3922829968184026...
# 2  [[61, 0, 281.3701299412495, -0.064340020292604...
# 3  [[20, 0, 281.3701299412495, -1.344685088282919...
# 4  [[15, 0, 281.3701299412495, -0.959526381657648...

# %%
df.describe()
# Out:
#        action_history  rewards_history
# count      200.000000       200.000000
# mean        14.745000       127.365988
# std          8.677353       241.715555
# min          0.000000         0.000000
# 25%          7.000000         0.000000
# 50%         15.000000         0.000000
# 75%         22.000000       208.524614
# max         29.000000       957.984943

# %%
df[df['rewards_history']==0].count()
# Out:
# action_history     137
# rewards_history    137
# state_history      137
# dtype: int64

# %%
users_items_df = []
for i in range(df.shape[0]):
    users_items_df += df['state_history'][i] 
    
users_items_df = pd.DataFrame(users_items_df,columns = ['user_id','item_id',
                                                        'price','v1','v2','v3','v4','v5'])
users_items_df[users_items_df['user_id']== 26]
# Out:
#       user_id  item_id       price        v1        v2        v3        v4  \
# 2714       26        0  281.370130  0.543994  0.992549 -0.205376  0.473626
# 2715       26        1   95.453526  0.543994  0.992549 -0.401835  2.038535
# 2716       26        2  434.677578  0.543994  0.992549  0.373717  0.849216
# 2717       26        3  299.015406  0.543994  0.992549  1.735018  1.687989
# 2718       26        4  223.344537  0.543994  0.992549  3.085611  0.529372
# 2719       26        5  337.393735  0.543994  0.992549 -0.128959  3.466078
# 2720       26        6  747.061946  0.543994  0.992549  0.069681  1.098576
# 2721       26        7   61.085024  0.543994  0.992549  0.044821  0.495376
# 2722       26        8  347.665228  0.543994  0.992549  2.093302  0.514336
# 2723       26        9  645.518587  0.543994  0.992549  2.163980 -0.030976
# 2724       26       10  821.583584  0.543994  0.992549  0.470875  1.641579
# 2725       26       11  102.941312  0.543994  0.992549 -0.247538  1.456002
# 2726       26       12  411.647736  0.543994  0.992549  1.951084  0.487085
# 2727       26       13  957.984943  0.543994  0.992549  0.639274  0.407963
# 2728       26       14  884.809527  0.543994  0.992549 -0.273496  1.245878
# 2729       26       15  259.522792  0.543994  0.992549  0.399180  0.432390
# 2730       26       16  925.267997  0.543994  0.992549  0.474289  0.715093
# 2722  0.177684
# 2723  1.954202
# 2724  1.849172
# 2725  0.061771
# 2726 -0.898024
# 2727  0.762647
# 2728  0.983959
# 2729  0.662066
# 2730  0.154725
# 2731  1.197391
# 2732 -0.237311
# 2733  1.607643
# 2734  2.638473
# 2735 -0.079712
# 2736  2.579201
# 2737 -0.035058
# 2738 -1.364074
# 2739  0.806836
# 2740  1.454708
# 2741  2.451879
# 2742 -0.634151
# 2743  0.709418
# ...        ...
# 5757  1.518943
# 5758  0.007024
# 5759  2.297880
# 5760  2.182950
# 5761 -0.398965
# 5762 -0.245175
# 5763  0.233191
# 5764  1.852251
# 5765 -0.270090
# 5766  1.658729
# 5767  0.156934
# 5768  1.263901
# 5769  0.095548
# 5770 -0.563057
# 5771  1.779646
# 5772  0.528060
# 5773  0.233514
# 5774  1.232669
# 5775  2.622541
# 5776  1.841731
# 5777  1.875827
# 5778  1.965974
# 5779  2.562622
# 5780  0.362871
# 5781  2.066859
# 5782  0.069090
# 5783  1.275317
# 5784 -0.262575
# 5785  0.771373
# 5786 -0.596394
#
# [90 rows x 8 columns]

# %%
pos_df = df[df["rewards_history"] > 0].reset_index(drop=True)
neg_df = df[df["rewards_history"] == 0].reset_index(drop=True)

# %%
pos_df["user_id"] = [pos_df["state_history"][i][0][0] for i in range(pos_df.shape[0])]
pos_df["item_id_action"] = [pos_df["state_history"][i][pos_df["action_history"][i]][1] for i in range(pos_df.shape[0])]
pos_df.head()## There are some users that have more than one positive item
# Out:
#    action_history  rewards_history  \
# 0               9       645.518587
# 1              11       102.941312
# 2              16       925.267997
# 3               5       337.393735
# 4              25       249.038114
#
#                                        state_history  user_id  item_id_action
# 0  [[10, 0, 281.3701299412495, 1.3366397537036412...       10               9
# 1  [[69, 0, 281.3701299412495, 0.3922829968184026...       69              11
# 2  [[61, 0, 281.3701299412495, -0.064340020292604...       61              16
# 3  [[20, 0, 281.3701299412495, -1.344685088282919...       20               5
# 4  [[15, 0, 281.3701299412495, -0.959526381657648...       15              25

# %%
data = df.copy()
data["item_id_action"] = [data["state_history"][i][data["action_history"][i]][1] for i in range(data.shape[0])]

for index, row in data.iterrows():
    for index,list_ in enumerate(row['state_history']):
        if(index == row['action_history'] and row['rewards_history']!=0):
            list_.extend([1])
        else:
            list_.extend([0])

# %%
users_items_df = []
for i in range(df.shape[0]):
    users_items_df += data['state_history'][i] 
    
users_items_df = pd.DataFrame(users_items_df,columns = ['user_id','item_id',
                                                        'price','v1','v2','v3','v4','v5',
                                                        'item_recommended'])
users_items_df
# Out:
#       user_id  item_id       price        v1        v2        v3        v4  \
# 0          10        0  281.370130  1.336640  0.686052 -0.205376  0.473626
# 1          10        1   95.453526  1.336640  0.686052 -0.401835  2.038535
# 2          10        2  434.677578  1.336640  0.686052  0.373717  0.849216
# 3          10        3  299.015406  1.336640  0.686052  1.735018  1.687989
# 4          10        4  223.344537  1.336640  0.686052  3.085611  0.529372
# 5          10        5  337.393735  1.336640  0.686052 -0.128959  3.466078
# 6          10        6  747.061946  1.336640  0.686052  0.069681  1.098576
# 7          10        7   61.085024  1.336640  0.686052  0.044821  0.495376
# 5932       78       25  249.038114  1.054374  0.154269  1.168253  1.093627
# 5933       78       26  222.160402  1.054374  0.154269  0.766778  0.808158
# 5934       78       27  309.355817  1.054374  0.154269  1.602914  2.169745
# 5935       78       28  827.332266  1.054374  0.154269  1.378565 -0.942638
# 5936       78       29   96.335618  1.054374  0.154269  1.029242  2.098834
#
#             v5  item_recommended
# 0     0.689241                 0
# 1     1.014842                 0
# 2     1.448004                 0
# 3     0.731074                 0
# 4     0.355602                 0
# 5     1.373371                 0
# 6     0.892533                 0
# 7    -0.315624                 0
# 8     0.410930                 0
# 9     0.108593                 1
# 10    0.149022                 0
# 11    1.919652                 0
# 12    1.759899                 0
# 13    0.437338                 0
# 14    0.436925                 0
# 15    1.234231                 0
# 16    0.767138                 0
# 17    2.012376                 0
# 18    0.060443                 0
# 19    0.194647                 0
# 20    1.268076                 0
# 21    1.355067                 0
# 22    0.015097                 0
# 23    1.964225                 0
# 24    1.082428                 0
# 25    0.540654                 0
# 26    0.872745                 0
# 27    0.647559                 0
# 28    3.612940                 0
# 29    2.151010                 0
# ...        ...               ...
# 5907  0.529339                 0
# 5908 -0.561924                 0
# 5909  0.236051                 0
# 5910  1.078501                 0
# 5911  2.510743                 0
# 5912  0.407394                 0
# 5913  0.599153                 0
# 5914  0.762417                 0
# 5915  2.501600                 0
# 5916  0.239743                 0
# 5917  1.674812                 0
# 5918 -0.893103                 0
# 5919 -0.315502                 0
# 5920 -1.624710                 0
# 5921  2.067546                 0
# 5922  1.388258                 0
# 5923  3.404735                 0
# 5924  1.455210                 0
# 5925  2.703444                 0
# 5926 -0.086930                 0
# 5927 -0.569812                 0
# 5928  2.019262                 0
# 5929 -0.042874                 0
# 5930  0.628105                 0
# 5931  0.022436                 0
# 5932  1.076785                 0
# 5933  0.662695                 0
# 5934  1.974917                 0
# 5935  0.463844                 0
# 5936  4.144473                 0
#
# [5937 rows x 9 columns]

# %%
from tffm import TFFMClassifier
import tensorflow as tf

model = TFFMClassifier(
    order=2,
    pos_class_weight=6.0,
    rank=10, 
    optimizer=tf.train.AdamOptimizer(learning_rate=0.001), 
    n_epochs=50, 
    batch_size=1024,
    init_std=0.001,
    reg=0.01,
    input_type='dense',
    seed=42
)

X = users_items_df.loc[:, users_items_df.columns != 'item_recommended'].drop(['user_id','item_id'],axis=1).values
y = users_items_df.loc[:,'item_recommended'].values

# %%
model.fit(X, y, show_progress=True)
# Out:
# 100%|██████████| 50/50 [00:00<00:00, 91.37epoch/s]

# %%
# Out:
# 7

# %%
generations = 300
params = {'user_id': USER_ID}
params['recommended_item'] = predicted_item

next_state_df = pd.DataFrame(next_state,columns = ['user_id','item_id',
                                    'price','v1','v2','v3',
                                    'v4','v5',])
X_predict = next_state_df.drop(['user_id','item_id'],axis=1).values
predicted_item = np.argmax(model.predict_proba(X_predict)[:,1])

for j in range(generations):
    r = requests.get(url=url_predict, params=params).json()
    reward = r['reward']
    total_reward += reward
    next_state = r['state']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-113-d6dbdc81ad1c> in <module>
#       1
#       2 params = {'user_id': USER_ID}
# ----> 3 params['recommended_item'] = predicted_item
#       4
#       5 r = requests.get(url=url_predict, params=params).json()
#
# NameError: name 'predicted_item' is not defined
